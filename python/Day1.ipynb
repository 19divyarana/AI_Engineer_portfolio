# %% [markdown]
# # Basics/Tracing

# %%
a = 10
b = a

a = 20

print(a)
print(b)
# Out:
# 20
# 10

# %%
x = 10
y = 10
print(id(x))
print(id(y))
print(id(x) == id(y))
# Out:
# 140712185935048
# 140712185935048
# True

# %%
result = 10 + 5.5

print(type(result))
# Out:
# <class 'float'>

# %%
print(bool(""))
print(bool(" "))
print(bool(0))
print(bool(-1))
# Out:
# False
# True
# False
# True

# %%
a = "100"

print(int(a) + 50)
# Out:
# 150

# %%
x = "10.5"

print(int(x))
#why it fails?
# Out:
# 105

# %%
print(bool([]))
print(bool([0]))
# Out:
# False
# True

# %%
print(10 // 3)
print(10 % 3)
print(10 ** 2)
# Out:
# 3
# 1
# 100

# %%
print(True + True)
print(False + True)
# Out:
# 2
# 1

# %%
print("a" in "apple")
print("z" in "apple")
# Out:
# True
# False

# %%
x = [1, 2]

y = x

print(x is y)
print(x == y)
# Out:
# True
# True

# %%
x = 5

if x > 2:
    if x > 4:
        print("A")
    else:
        print("B")
else:
    print("C")
# Out:
# A

# %%
a=int(input())
if a >0:
    print("Positive")
else:
    print("Negative")
# Out:
#  10
# Positive

# %%
a=2
b=5
c=6
if a>b and a>c:
    print(a)
elif b>c:
    print(b)
else:
    print(c)
# Out:
# 6

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
